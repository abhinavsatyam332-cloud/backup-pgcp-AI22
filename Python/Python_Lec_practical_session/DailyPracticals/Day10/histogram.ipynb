# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ages= [22, 55, 62, 45, 21, 22, 34, 42, 42, 4, 99, 102, 110, 120, 121, 122, 130, 111]
bins = [20,30,40,50,60]

# %%
plt.hist(ages, bins, edgecolor='black')
# Out:
# (array([3., 1., 3., 1.]),
#  array([20., 30., 40., 50., 60.]),
#  <BarContainer object of 4 artists>)
