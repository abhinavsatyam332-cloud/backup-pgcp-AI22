# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('diamonds')
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.scatterplot(df,x='carat',y='price')
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(df,x='carat',y='price',hue='cut')
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
df_f = df.sample(20)
print(df_f.head())
print(df_f.shape)
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 46258   0.54    Ideal     G     VS1   61.3   57.0   1754  5.25  5.28  3.23
# 42762   0.56  Premium     G     SI1   62.8   55.0   1345  5.28  5.26  3.31
# 6868    0.91  Premium     H     VS2   61.0   59.0   4128  6.32  6.27  3.84
# 21797   1.02    Ideal     F    VVS2   60.9   56.0   9870  6.54  6.49  3.97
# 5520    1.00  Premium     H     SI2   61.2   59.0   3850  6.38  6.42  3.92
# (20, 10)

# %%
sns.scatterplot(df_f,x='carat',y='price')
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(df_f,x='carat',y='price',hue='cut')
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(df_f,x='carat',y='price',hue='cut',size='cut')
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(df_f,x='carat',y='price',hue='cut',style='cut')
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(df_f,x='carat',y='price',hue='cut',style='cut',alpha = 0.5)
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(df_f,x='carat',y='price',hue='clarity',style='cut',alpha = 0.5,size='cut')
# Out:
# <Axes: xlabel='carat', ylabel='price'>
