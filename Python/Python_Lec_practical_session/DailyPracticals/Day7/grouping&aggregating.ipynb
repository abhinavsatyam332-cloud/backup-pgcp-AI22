# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('survey_results.csv')
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df['ConvertedCompYearly'].min()
# Out:
# np.float64(1.0)

# %%
df['ConvertedCompYearly'].max()
# Out:
# np.float64(74351432.0)

# %%
df['YearsCode'].dtype
# Out:
# dtype('O')

# %%
df['ConvertedCompYearly'].mean()
# Out:
# np.float64(103110.08171765343)

# %%
# df['YearsCode'].mean()

# %%
df['YearsCode'].value_counts()
# Out:
# YearsCode
# 10                    6521
# 5                     5415
# 6                     4893
# 8                     4879
# 7                     4800
# 4                     4466
# 15                    4336
# 3                     4269
# 20                    4021
# 12                    3471
# 9                     3130
# 2                     2826
# 25                    2685
# 13                    2601
# 11                    2519
# 14                    2278
# 30                    2078
# 16                    1842
# 18                    1690
# 17                    1544
# 23                    1327
# 40                    1302
# 1                     1294
# 22                    1210
# 35                    1118
# Less than 1 year       968
# 24                     959
# 19                     826
# 21                     761
# 28                     715
# 27                     710
# 26                     706
# 33                     496
# 32                     444
# ...

# %%
df['YearsCode'].nunique()
# Out:
# 52

# %%
df['YearsCode'].count()
# Out:
# np.int64(87435)

# %%
df['ConvertedCompYearly'].agg(['min','mean','max'])
# Out:
# min     1.000000e+00
# mean    1.031101e+05
# max     7.435143e+07
# Name: ConvertedCompYearly, dtype: float64

# %%
countries = df.groupby('Country')
countries

# %%
india = countries.get_group('India')
india
# Out:
#        ResponseId     Q120                                         MainBranch  \
# 9              10  I agree                     I am a developer by profession
# 66             67  I agree                     I am a developer by profession
# 78             79  I agree                     I am a developer by profession
# 82             83  I agree                     I am a developer by profession
# 85             86  I agree                     I am a developer by profession
# ...           ...      ...                                                ...
# 89119       89120  I agree                     I am a developer by profession
# 89121       89122  I agree  I am not primarily a developer, but I write co...
# 89164       89165  I agree                     I am a developer by profession
# 89165       89166  I agree                     I am a developer by profession
# 89167       89168  I agree                     I am a developer by profession
#
# ...

# %%
countries['YearsCode'].value_counts()
# Out:
# Country      YearsCode
# Afghanistan  3            8
#              10           6
#              1            5
#              2            5
#              4            5
#                          ..
# Zimbabwe     10           2
#              1            1
#              13           1
#              20           1
#              7            1
# Name: count, Length: 4025, dtype: int64

# %%
countries['ConvertedCompYearly'].agg(['min','mean','max'])
# Out:
#                                           min           mean        max
# Country
# Afghanistan                              33.0  843636.090909  9203683.0
# Albania                                  14.0   29219.450000   139700.0
# Algeria                                 512.0   10069.190476    37776.0
# Andorra                               23560.0  120368.800000   289142.0
# Angola                                  662.0    4302.000000     7942.0
# ...                                       ...            ...        ...
# Venezuela, Bolivarian Republic of...      5.0   23068.851852   180000.0
# Viet Nam                                  1.0   20995.956140   125000.0
# Yemen                                  1500.0   15089.333333    59917.0
# Zambia                                  605.0   13897.800000    41122.0
# Zimbabwe                               3000.0   26740.000000   114000.0
#
# [185 rows x 3 columns]

# %%
countries.get_group('India')['ConvertedCompYearly'].agg(['min','mean','max'])
# Out:
# min          1.000000
# mean     27346.822805
# max     424091.000000
# Name: ConvertedCompYearly, dtype: float64

# %%
# df['YearsCode'].min()
df['YearsCode'] = pd.to_numeric(df['YearsCode'], errors = 'coerce')
df['YearsCode']
# Out:
# 0         NaN
# 1        18.0
# 2        27.0
# 3        12.0
# 4         6.0
#          ...
# 89179    20.0
# 89180     5.0
# 89181    10.0
# 89182     3.0
# 89183    17.0
# Name: YearsCode, Length: 89184, dtype: float64

# %%
# df['YearsCode'].replace({'':''})
