# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('Data.tsv' , delimiter = '\t')

# %%
df=pd.read_csv('survey_results.csv')
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df
# Out:
#                    Name                       Position         Office  Age  \
# 0            Airi Satou                     Accountant          Tokyo   33
# 1        Angelica Ramos  Chief Executive Officer (CEO)         London   47
# 2            Ashton Cox        Junior Technical Author  San Francisco   66
# 3         Bradley Greer              Software Engineer         London   41
# 4        Brenden Wagner              Software Engineer  San Francisco   28
# 5    Brielle Williamson         Integration Specialist       New York   61
# 6            Bruno Nash              Software Engineer         London   38
# 7          Caesar Vance              Pre-Sales Support       New York   21
# 8          Cara Stevens                Sales Assistant       New York   46
# 9          Cedric Kelly    Senior Javascript Developer      Edinburgh   22
# 10      Charde Marshall              Regional Director  San Francisco   36
# ...

# %%
df.tail()
# Out:
#               Name                       Position         Office  Age  \
# 53  Vivian Harrell           Financial Controller  San Francisco   62
# 54      Yuri Berry  Chief Marketing Officer (CMO)       New York   40
# 55   Zenaida Frank              Software Engineer       New York   63
# 56  Zorita Serrano              Software Engineer  San Francisco   56
# 57            Name                       Position         Office  Age
#
#     Start date    Salary
# 53  2009-02-14  $452,500
# 54  2009-06-25  $675,000
# 55  2010-01-04  $125,250
# 56  2012-06-01  $115,000
# 57  Start date    Salary

# %%
df.columns
# Out:
# Index(['ResponseId', 'Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
# ...

# %%
df.head(10)
# Out:
#    ResponseId     Q120                                         MainBranch  \
# 0           1  I agree                                      None of these
# 1           2  I agree                     I am a developer by profession
# 2           3  I agree                     I am a developer by profession
# 3           4  I agree                     I am a developer by profession
# 4           5  I agree                     I am a developer by profession
# 5           6  I agree                     I am a developer by profession
# 6           7  I agree                     I am a developer by profession
# 7           8  I agree                     I am a developer by profession
# 8           9  I agree  I am not primarily a developer, but I write co...
# 9          10  I agree                     I am a developer by profession
#
#                Age                                         Employment  \
# 0  18-24 years old                                                NaN
# ...

# %%
df.tail()
# Out:
#        ResponseId     Q120                      MainBranch  \
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 89179     25-34 years old  Employed, full-time;Independent contractor, fr...
# 89180     18-24 years old             Student, full-time;Employed, part-time
# 89181   Prefer not to say                                I prefer not to say
# 89182  Under 18 years old             Employed, part-time;Student, part-time
# 89183     35-44 years old                                Employed, full-time
#
#                                  RemoteWork  \
# 89179                                Remote
# 89180  Hybrid (some remote, some in-person)
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 89184 entries, 0 to 89183
# Data columns (total 84 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ResponseId                           89184 non-null  int64
#  1   Q120                                 89184 non-null  str
#  2   MainBranch                           89184 non-null  str
#  3   Age                                  89184 non-null  str
#  4   Employment                           87898 non-null  str
#  5   RemoteWork                           73810 non-null  str
#  6   CodingActivities                     73764 non-null  str
#  7   EdLevel                              87973 non-null  str
#  8   LearnCode                            87663 non-null  str
#  9   LearnCodeOnline                      70084 non-null  str
#  10  LearnCodeCoursesCert                 37076 non-null  str
# ...

# %%
df.describe()
# Out:
#          ResponseId     CompTotal       WorkExp  ConvertedCompYearly
# count  89184.000000  4.822500e+04  43579.000000         4.801900e+04
# mean   44592.500000  1.036807e+42     11.405126         1.031101e+05
# std    25745.347541  2.276847e+44      9.051989         6.814188e+05
# min        1.000000  0.000000e+00      0.000000         1.000000e+00
# 25%    22296.750000  6.300000e+04      5.000000         4.390700e+04
# 50%    44592.500000  1.150000e+05      9.000000         7.496300e+04
# 75%    66888.250000  2.300000e+05     16.000000         1.216410e+05
# max    89184.000000  5.000000e+46     50.000000         7.435143e+07

# %%
df.describe().map(lambda x: f'{x: .0f}')
# Out:
#       ResponseId                                         CompTotal WorkExp  \
# count      89184                                             48225   43579
# mean       44592       1036806635562467391394372602402550216392704      11
# std        25745     227684720124393422298755801637800141977026560       9
# min            1                                                 0       0
# 25%        22297                                             63000       5
# 50%        44592                                            115000       9
# 75%        66888                                            230000      16
# max        89184   49999999999999992051087350427974655758076739584      50
#
#       ConvertedCompYearly
# count               48019
# mean               103110
# std                681419
# min                     1
# 25%                 43907
# 50%                 74963
# 75%                121641
# max              74351432

# %%
df = pd.read_csv('Data.tsv', delimiter = '\t')
df
# Out:
#                    Name                       Position         Office  Age  \
# 0            Airi Satou                     Accountant          Tokyo   33
# 1        Angelica Ramos  Chief Executive Officer (CEO)         London   47
# 2            Ashton Cox        Junior Technical Author  San Francisco   66
# 3         Bradley Greer              Software Engineer         London   41
# 4        Brenden Wagner              Software Engineer  San Francisco   28
# 5    Brielle Williamson         Integration Specialist       New York   61
# 6            Bruno Nash              Software Engineer         London   38
# 7          Caesar Vance              Pre-Sales Support       New York   21
# 8          Cara Stevens                Sales Assistant       New York   46
# 9          Cedric Kelly    Senior Javascript Developer      Edinburgh   22
# 10      Charde Marshall              Regional Director  San Francisco   36
# ...

# %%
df = pd.read_csv('Transaction.txt', sep = '|')

# %%
df
# Out:
#   TransactionID        Date CustomerType ProductCategory  Quantity   Price  \
# 0       TXN1001  2026-06-01       Member     Electronics         1  599.99
# 1       TXN1002  2026-06-01       Normal        Clothing         3   25.50
# 2       TXN1003  2026-06-02       Member      Home Goods         2   45.00
# 3       TXN1004  2026-06-02       Normal     Electronics         1  120.00
# 4       TXN1005  2026-06-03       Member        Clothing         2   89.99
# 5       TXN1006  2026-06-03       Normal           Books         4   12.99
#
#   StoreLocation  PaymentMethod
# 0      New York    Credit Card
# 1   Los Angeles           Cash
# 2       Chicago  Mobile Wallet
# 3      New York    Credit Card
# 4       Chicago    Credit Card
# 5   Los Angeles           Cash

# %%
df = pd.read_excel('Financial Sample.xlsx')
df
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera           NaN
# 1          Government                   Germany  Carretera           NaN
# 2           Midmarket                    France  Carretera           NaN
# 3           Midmarket                   Germany  Carretera           NaN
# 4           Midmarket                    Mexico  Carretera           NaN
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %%
df.to_excel('Financial Sample2.xlsx')
