# %%
import pandas as pd
import numpy as np

# %%
arr = np.array([10,20,30,40,50])
series = pd.Series(arr)
series
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
names = ['Akshay','Amol','Aryan']
series = pd.Series(names)
series
# Out:
# 0    Akshay
# 1      Amol
# 2     Aryan
# dtype: object

# %%
head = pd.Series({'India':'Delhi',"Uk":"London","America":"New York","France":"Paris"})
head
# Out:
# India         Delhi
# Uk           London
# America    New York
# France        Paris
# dtype: object

# %%
head.index
# Out:
# Index(['India', 'Uk', 'America', 'France'], dtype='object')

# %%
head.values
# Out:
# array(['Delhi', 'London', 'New York', 'Paris'], dtype=object)

# %%
head.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of India         Delhi
# Uk           London
# America    New York
# France        Paris
# dtype: object>

# %%
head.loc['India']
# Out:
# 'Delhi'

# %%
head.iloc[2]
# Out:
# 'New York'

# %%
head['India':'America']
# Out:
# India         Delhi
# Uk           London
# America    New York
# dtype: object

# %%
head[1:4]
# Out:
# Uk           London
# America    New York
# France        Paris
# dtype: object

# %%
count = pd.Series({'America':30,'India':75,'France':15,'Uk':69})

# %%
count
# Out:
# America    [30, 40, 50]
# India      [75, 65, 55]
# France     [15, 25, 35]
# Uk         [69, 59, 49]
# dtype: object

# %%
df = pd.DataFrame({'Head Office':head,'Count':count})
df
# Out:
#         Head Office  Count
# America    New York     30
# France        Paris     15
# India         Delhi     75
# Uk           London     69

# %%
df = pd.DataFrame({
    'Name': ['Akshay',"Amol",'aryan','ayush'],
    'Age' : [33,28,40,39],
    'City': ['Pune','Pune','Delhi','Delhi']

})  
df
# Out:
#      Name  Age   City
# 0  Akshay   33   Pune
# 1    Amol   28   Pune
# 2   aryan   40  Delhi
# 3   ayush   39  Delhi

# %%
df  = pd.DataFrame(data = [[500,15,40],[400,12,30],
                           [250,13,15],[300,14,15]],
                   index = ['Tata','Maruti','Hyundai','Honda'],
                   columns = ['Total Sale','Profit %','Market Share'])
df
# Out:
#          Total Sale  Profit %  Market Share
# Tata            500        15            40
# Maruti          400        12            30
# Hyundai         250        13            15
# Honda           300        14            15

# %%
df.loc['Tata']
# Out:
# Total Sale      500
# Profit %         15
# Market Share     40
# Name: Tata, dtype: int64

# %%
df.iloc[-2]
# Out:
# Total Sale      250
# Profit %         13
# Market Share     15
# Name: Hyundai, dtype: int64

# %%
df.iloc[3]
# Out:
# Total Sale      300
# Profit %         14
# Market Share     15
# Name: Honda, dtype: int64

# %%
df['Tata':'Hyundai']
# Out:
#          Total Sale  Profit %  Market Share
# Tata            500        15            40
# Maruti          400        12            30
# Hyundai         250        13            15

# %%
df.loc['Tata':'Hyundai','Profit %']
# Out:
# Tata       15
# Maruti     12
# Hyundai    13
# Name: Profit %, dtype: int64

# %%
df.iloc[1:3,1:2]
# Out:
#          Profit %
# Maruti         12
# Hyundai        13

# %%
df.iloc[1:3,2]
# Out:
# Maruti     30
# Hyundai    15
# Name: Market Share, dtype: int64
