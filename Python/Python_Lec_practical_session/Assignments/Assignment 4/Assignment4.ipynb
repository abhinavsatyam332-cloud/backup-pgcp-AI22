# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Q1. Create a DataFrame containing student information like Name, Age, Department, %Marks
#
# a.	Display column names of the DF
#
# b.	Show min/max and average marks
#
# c.	Get unique values and student count for each Department

# %%
data = {
    'Name': ['Alice Smith', 'Bob Jones', 'Charlie Brown', 'Diana Prince', 'Ethan Hunt', 'Fiona Gallagher'],
    'Age': [21, 22, 20, 23, 21, 22],
    'Department': ['Computer Science', 'Mathematics', 'Physics', 'Biology', 'Chemistry', 'Computer Science'],
    '% Marks': [88.5, 76.0, 92.3, 81.5, 95.0, 79.4]
}

# %%
df = pd.DataFrame(data=data)
df
# Out:
#               Name  Age        Department  % Marks
# 0      Alice Smith   21  Computer Science     88.5
# 1        Bob Jones   22       Mathematics     76.0
# 2    Charlie Brown   20           Physics     92.3
# 3     Diana Prince   23           Biology     81.5
# 4       Ethan Hunt   21         Chemistry     95.0
# 5  Fiona Gallagher   22  Computer Science     79.4

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Department', '% Marks'], dtype='str')

# %%
df['% Marks'].min()
# Out:
# np.float64(76.0)

# %%
df['% Marks'].max()
# Out:
# np.float64(95.0)

# %%
df['% Marks'].mean()
# Out:
# np.float64(85.45)

# %%
df.groupby(['Department']).count()['Name']
# Out:
# Department
# Biology             1
# Chemistry           1
# Computer Science    2
# Mathematics         1
# Physics             1
# Name: Name, dtype: int64

# %%
df['Department'].value_counts()
# Out:
# Department
# Computer Science    2
# Mathematics         1
# Physics             1
# Biology             1
# Chemistry           1
# Name: count, dtype: int64

# %%
df['Department'].unique()
# Out:
# <ArrowStringArray>
# ['Computer Science', 'Mathematics', 'Physics', 'Biology', 'Chemistry']
# Length: 5, dtype: str

# %% [markdown]
# Q2. Read csv file solar.csv
#
# a.	Display all the plants with capacity > 500 MW
#
# b.	Display plant details for New York plant
#
# c.	For all the plants display Average MW Per Plant and Generation (GWh)
#
# d.	Sort the plants by Generation (GWh) (ascending) and Installed Capacity (MW)(descending)
#
# e.	List top 5 plants for their Generation
#
# f.	Display all plant details for states – California, Nevada, Arizona and Texas
#
# g.	Group the plants by region, find – min/max capacity plant for each group
#
# h.	Add following information to the existing details for the plants
#
# 	North Carolina	148	669	4.5	1162	North

# %%
df = pd.read_csv('solar.csv')
df
# Out:
#          State  Number of Solar Plants  Installed Capacity (MW)  \
# 0   California                     289                     4395
# 1      Arizona                      48                     1078
# 2       Nevada                      11                      238
# 3      Chicago                      33                      261
# 4  Connecticut                      20                      118
# 5        Texas                      12                      187
# 6     New York                      13                       53
# 7      Florida                      15                      535
#
#    Average MW Per Plant  Generation (GWh) Region
# 0                  15.3             10826   West
# 1                  22.5              2550   West
# 2                  21.6               557   West
# 3                   7.9               590  North
# 4                   5.9               235   East
# 5                  15.6               354  South
# ...

# %%
df[df['Installed Capacity (MW)'] > 500]
# Out:
#         State  Number of Solar Plants  Installed Capacity (MW)  \
# 0  California                     289                     4395
# 1     Arizona                      48                     1078
# 7     Florida                      15                      535
#
#    Average MW Per Plant  Generation (GWh) Region
# 0                  15.3             10826   West
# 1                  22.5              2550   West
# 7                  12.3               453  South

# %%
df.iloc[6]
# Out:
# State                      New York
# Number of Solar Plants           13
# Installed Capacity (MW)          53
# Average MW Per Plant            4.1
# Generation (GWh)                 84
# Region                         East
# Name: 6, dtype: object

# %%
df[df['State'] == 'New York']
# Out:
#       State  Number of Solar Plants  Installed Capacity (MW)  \
# 6  New York                      13                       53
#
#    Average MW Per Plant  Generation (GWh) Region
# 6                   4.1                84   East

# %%
df.query("State == 'New York'")
# Out:
#       State  Number of Solar Plants  Installed Capacity (MW)  \
# 6  New York                      13                       53
#
#    Average MW Per Plant  Generation (GWh) Region
# 6                   4.1                84   East

# %%
df[['State','Average MW Per Plant',	'Generation (GWh)']]
# Out:
#          State  Average MW Per Plant  Generation (GWh)
# 0   California                  15.3             10826
# 1      Arizona                  22.5              2550
# 2       Nevada                  21.6               557
# 3      Chicago                   7.9               590
# 4  Connecticut                   5.9               235
# 5        Texas                  15.6               354
# 6     New York                   4.1                84
# 7      Florida                  12.3               453

# %%
df
# Out:
#          State  Number of Solar Plants  Installed Capacity (MW)  \
# 0   California                     289                     4395
# 1      Arizona                      48                     1078
# 2       Nevada                      11                      238
# 3      Chicago                      33                      261
# 4  Connecticut                      20                      118
# 5        Texas                      12                      187
# 6     New York                      13                       53
# 7      Florida                      15                      535
#
#    Average MW Per Plant  Generation (GWh) Region
# 0                  15.3             10826   West
# 1                  22.5              2550   West
# 2                  21.6               557   West
# 3                   7.9               590  North
# 4                   5.9               235   East
# 5                  15.6               354  South
# ...

# %%
df.sort_values(['Generation (GWh)'])
# Out:
#          State  Number of Solar Plants  Installed Capacity (MW)  \
# 6     New York                      13                       53
# 4  Connecticut                      20                      118
# 5        Texas                      12                      187
# 7      Florida                      15                      535
# 2       Nevada                      11                      238
# 3      Chicago                      33                      261
# 1      Arizona                      48                     1078
# 0   California                     289                     4395
#
#    Average MW Per Plant  Generation (GWh) Region
# 6                   4.1                84   East
# 4                   5.9               235   East
# 5                  15.6               354  South
# 7                  12.3               453  South
# 2                  21.6               557   West
# 3                   7.9               590  North
# ...

# %%
df.sort_values(['Installed Capacity (MW)'],ascending=False)
# Out:
#          State  Number of Solar Plants  Installed Capacity (MW)  \
# 0   California                     289                     4395
# 1      Arizona                      48                     1078
# 7      Florida                      15                      535
# 3      Chicago                      33                      261
# 2       Nevada                      11                      238
# 5        Texas                      12                      187
# 4  Connecticut                      20                      118
# 6     New York                      13                       53
#
#    Average MW Per Plant  Generation (GWh) Region
# 0                  15.3             10826   West
# 1                  22.5              2550   West
# 7                  12.3               453  South
# 3                   7.9               590  North
# 2                  21.6               557   West
# 5                  15.6               354  South
# ...

# %%
# df['Generation (GWh)'].sort_values(ascending=False)[:5]
df.sort_values(['Generation (GWh)'],ascending=False).head()
# Out:
#         State  Number of Solar Plants  Installed Capacity (MW)  \
# 0  California                     289                     4395
# 1     Arizona                      48                     1078
# 3     Chicago                      33                      261
# 2      Nevada                      11                      238
# 7     Florida                      15                      535
#
#    Average MW Per Plant  Generation (GWh) Region
# 0                  15.3             10826   West
# 1                  22.5              2550   West
# 3                   7.9               590  North
# 2                  21.6               557   West
# 7                  12.3               453  South

# %%
df.loc[df.State == 'California'  ]
# Out:
#         State  Number of Solar Plants  Installed Capacity (MW)  \
# 0  California                     289                     4395
#
#    Average MW Per Plant  Generation (GWh) Region
# 0                  15.3             10826   West

# %%
lst = ['California', 'Nevada', 'Arizona', 'Texas']
# filter = df['State'] >'d'

# print(filter)
filter = df['State'].isin(lst) 

df.loc[filter]
# Out:
#         State  Number of Solar Plants  Installed Capacity (MW)  \
# 0  California                     289                     4395
# 1     Arizona                      48                     1078
# 2      Nevada                      11                      238
# 5       Texas                      12                      187
#
#    Average MW Per Plant  Generation (GWh) Region
# 0                  15.3             10826   West
# 1                  22.5              2550   West
# 2                  21.6               557   West
# 5                  15.6               354  South

# %%
df
# Out:
#          State  Number of Solar Plants  Installed Capacity (MW)  \
# 0   California                     289                     4395
# 1      Arizona                      48                     1078
# 2       Nevada                      11                      238
# 3      Chicago                      33                      261
# 4  Connecticut                      20                      118
# 5        Texas                      12                      187
# 6     New York                      13                       53
# 7      Florida                      15                      535
#
#    Average MW Per Plant  Generation (GWh) Region
# 0                  15.3             10826   West
# 1                  22.5              2550   West
# 2                  21.6               557   West
# 3                   7.9               590  North
# 4                   5.9               235   East
# 5                  15.6               354  South
# ...

# %%
df.groupby(by=['Region'])['Number of Solar Plants'].min()
# Out:
# Region
# East     13
# North    33
# South    12
# West     11
# Name: Number of Solar Plants, dtype: int64

# %%
df.groupby(by=['Region'])['Number of Solar Plants'].max()
# Out:
# Region
# East      20
# North     33
# South     15
# West     289
# Name: Number of Solar Plants, dtype: int64

# %%
df
# Out:
#          State  Number of Solar Plants  Installed Capacity (MW)  \
# 0   California                     289                     4395
# 1      Arizona                      48                     1078
# 2       Nevada                      11                      238
# 3      Chicago                      33                      261
# 4  Connecticut                      20                      118
# 5        Texas                      12                      187
# 6     New York                      13                       53
# 7      Florida                      15                      535
#
#    Average MW Per Plant  Generation (GWh) Region
# 0                  15.3             10826   West
# 1                  22.5              2550   West
# 2                  21.6               557   West
# 3                   7.9               590  North
# 4                   5.9               235   East
# 5                  15.6               354  South
# ...

# %%
new_row = pd.DataFrame({ 'State':['Carolina'	],
                        'Number of Solar Plants': [148],	
                        'Installed Capacity (MW)': [669]	, 
                        'Average MW Per Plant' : [4.5]	, 
                        'Generation (GWh)': [1162]	,
                        'Region':['North']})

# %%
df.loc[len(df)] =[ 'Carolina'	,148	,669,	4.5	,1162	,'North']
df
# Out:
#          State  Number of Solar Plants  Installed Capacity (MW)  \
# 0   California                     289                     4395
# 1      Arizona                      48                     1078
# 2       Nevada                      11                      238
# 3      Chicago                      33                      261
# 4  Connecticut                      20                      118
# 5        Texas                      12                      187
# 6     New York                      13                       53
# 7      Florida                      15                      535
# 8     Carolina                     148                      669
#
#    Average MW Per Plant  Generation (GWh) Region
# 0                  15.3             10826   West
# 1                  22.5              2550   West
# 2                  21.6               557   West
# 3                   7.9               590  North
# 4                   5.9               235   East
# ...

# %%
pd.concat([df,new_row  ],ignore_index=True)
# Out:
#          State  Number of Solar Plants  Installed Capacity (MW)  \
# 0   California                     289                     4395
# 1      Arizona                      48                     1078
# 2       Nevada                      11                      238
# 3      Chicago                      33                      261
# 4  Connecticut                      20                      118
# 5        Texas                      12                      187
# 6     New York                      13                       53
# 7      Florida                      15                      535
# 8     Carolina                     148                      669
# 9     Carolina                     148                      669
#
#    Average MW Per Plant  Generation (GWh) Region
# 0                  15.3             10826   West
# 1                  22.5              2550   West
# 2                  21.6               557   West
# 3                   7.9               590  North
# ...

# %%
df.loc[df['State']=='California']
# Out:
#         State  Number of Solar Plants  Installed Capacity (MW)  \
# 0  California                     289                     4395
#
#    Average MW Per Plant  Generation (GWh) Region
# 0                  15.3             10826   West

# %%
df.iloc[0]
# Out:
# State                      California
# Number of Solar Plants            289
# Installed Capacity (MW)          4395
# Average MW Per Plant             15.3
# Generation (GWh)                10826
# Region                           West
# Name: 0, dtype: object

# %% [markdown]
# Q.3Read csv gapminder2007.csv
#
# a.	Display data for all Asian countries
#
# b.	Display top and bottom 15 rows
#
# c.	Show all the rows where life expectancy is more than 50 years and less than 80 years
#
# d.	Show data for India, America and France
#
# e.	Show data for all countries where name starts with ‘A’
#
# f.	Show min/max and mean GDP and Population for each continent
#
# g.	Show population and life expectancy for all countries
#
# h.	Sort the data by country names (ascending) and GDP (descending)
#
# i.	Find top 20 most populous countries
#
# j.	Delete all rows for a specific country
#
# k.	Change all column names to title case
#
# l.	Change column names: pop to Population, gdpPercap to GDP_Percap
#
# m.	Increase Life Expectancy by 2 years for all African countries
#
# n.	Find all the rows that contain NA values
#
# o.	Fill NA values with 0 for numeric columns

# %%
df = pd.read_csv('gapminder2007.csv')
df
# Out:
#                 country       pop continent  lifeExp     gdpPercap
# 0           Afghanistan  31889923      Asia   43.828    974.580338
# 1               Albania   3600523    Europe   76.423   5937.029526
# 2               Algeria  33333216    Africa   72.301   6223.367465
# 3                Angola  12420476    Africa   42.731   4797.231267
# 4             Argentina  40301927  Americas   75.320  12779.379640
# ..                  ...       ...       ...      ...           ...
# 137             Vietnam  85262356      Asia   74.249   2441.576404
# 138  West Bank and Gaza   4018332      Asia   73.422   3025.349798
# 139         Yemen, Rep.  22211743      Asia   62.698   2280.769906
# 140              Zambia  11746035    Africa   42.384   1271.211593
# 141            Zimbabwe  12311143    Africa   43.487    469.709298
#
# [142 rows x 5 columns]

# %%
df[df['continent'] == 'Asia']
# Out:
#                 country         pop continent  lifeExp     gdpPercap
# 0           Afghanistan    31889923      Asia   43.828    974.580338
# 7               Bahrain      708573      Asia   75.635  29796.048340
# 8            Bangladesh   150448339      Asia   64.062   1391.253792
# 18             Cambodia    14131858      Asia   59.723   1713.778686
# 24                China  1318683096      Asia   72.961   4959.114854
# 55     Hong Kong, China     6980412      Asia   82.208  39724.978670
# 58                India  1110396331      Asia   64.698   2452.210407
# 59            Indonesia   223547000      Asia   70.650   3540.651564
# 60                 Iran    69453570      Asia   70.964  11605.714490
# 61                 Iraq    27499638      Asia   59.545   4471.061906
# 63               Israel     6426679      Asia   80.745  25523.277100
# 66                Japan   127467972      Asia   82.603  31656.068060
# 67               Jordan     6053193      Asia   72.535   4519.461171
# ...

# %%
df.head(15)
# Out:
#                    country        pop continent  lifeExp     gdpPercap
# 0              Afghanistan   31889923      Asia   43.828    974.580338
# 1                  Albania    3600523    Europe   76.423   5937.029526
# 2                  Algeria   33333216    Africa   72.301   6223.367465
# 3                   Angola   12420476    Africa   42.731   4797.231267
# 4                Argentina   40301927  Americas   75.320  12779.379640
# 5                Australia   20434176   Oceania   81.235  34435.367440
# 6                  Austria    8199783    Europe   79.829  36126.492700
# 7                  Bahrain     708573      Asia   75.635  29796.048340
# 8               Bangladesh  150448339      Asia   64.062   1391.253792
# 9                  Belgium   10392226    Europe   79.441  33692.605080
# 10                   Benin    8078314    Africa   56.728   1441.284873
# 11                 Bolivia    9119152  Americas   65.554   3822.137084
# ...

# %%
df.tail(15)
# Out:
#                  country        pop continent  lifeExp     gdpPercap
# 127             Thailand   65068149      Asia   70.616   7458.396327
# 128                 Togo    5701579    Africa   58.420    882.969944
# 129  Trinidad and Tobago    1056608  Americas   69.819  18008.509240
# 130              Tunisia   10276158    Africa   73.923   7092.923025
# 131               Turkey   71158647    Europe   71.777   8458.276384
# 132               Uganda   29170398    Africa   51.542   1056.380121
# 133       United Kingdom   60776238    Europe   79.425  33203.261280
# 134        United States  301139947  Americas   78.242  42951.653090
# 135              Uruguay    3447496  Americas   76.384  10611.462990
# 136            Venezuela   26084662  Americas   73.747  11415.805690
# 137              Vietnam   85262356      Asia   74.249   2441.576404
# 138   West Bank and Gaza    4018332      Asia   73.422   3025.349798
# 139          Yemen, Rep.   22211743      Asia   62.698   2280.769906
# ...

# %%
df[(df['lifeExp'] > 50) & (df['lifeExp'] < 80)] 
# df.where(( (df['lifeExp'] > 50) & (df['lifeExp'] < 80) )).dropna()
# Out:
#                 country       pop continent  lifeExp     gdpPercap
# 1               Albania   3600523    Europe   76.423   5937.029526
# 2               Algeria  33333216    Africa   72.301   6223.367465
# 4             Argentina  40301927  Americas   75.320  12779.379640
# 6               Austria   8199783    Europe   79.829  36126.492700
# 7               Bahrain    708573      Asia   75.635  29796.048340
# ..                  ...       ...       ...      ...           ...
# 135             Uruguay   3447496  Americas   76.384  10611.462990
# 136           Venezuela  26084662  Americas   73.747  11415.805690
# 137             Vietnam  85262356      Asia   74.249   2441.576404
# 138  West Bank and Gaza   4018332      Asia   73.422   3025.349798
# 139         Yemen, Rep.  22211743      Asia   62.698   2280.769906
#
# [110 rows x 5 columns]

# %%
df
# Out:
#                 country       pop continent  lifeExp     gdpPercap
# 0           Afghanistan  31889923      Asia   43.828    974.580338
# 1               Albania   3600523    Europe   76.423   5937.029526
# 2               Algeria  33333216    Africa   72.301   6223.367465
# 3                Angola  12420476    Africa   42.731   4797.231267
# 4             Argentina  40301927  Americas   75.320  12779.379640
# ..                  ...       ...       ...      ...           ...
# 137             Vietnam  85262356      Asia   74.249   2441.576404
# 138  West Bank and Gaza   4018332      Asia   73.422   3025.349798
# 139         Yemen, Rep.  22211743      Asia   62.698   2280.769906
# 140              Zambia  11746035    Africa   42.384   1271.211593
# 141            Zimbabwe  12311143    Africa   43.487    469.709298
#
# [142 rows x 5 columns]

# %%
lst = ['India', 'America' , 'France']
df[df['country'].isin(lst)]
# Out:
#    country         pop continent  lifeExp     gdpPercap
# 44  France    61083916    Europe   80.657  30470.016700
# 58   India  1110396331      Asia   64.698   2452.210407

# %%
df[df['country'].str.startswith('A')]
# Out:
#        country       pop continent  lifeExp     gdpPercap
# 0  Afghanistan  31889923      Asia   43.828    974.580338
# 1      Albania   3600523    Europe   76.423   5937.029526
# 2      Algeria  33333216    Africa   72.301   6223.367465
# 3       Angola  12420476    Africa   42.731   4797.231267
# 4    Argentina  40301927  Americas   75.320  12779.379640
# 5    Australia  20434176   Oceania   81.235  34435.367440
# 6      Austria   8199783    Europe   79.829  36126.492700

# %%
# df.groupby(by=['continent']).agg(['min','max','mean'])
df.groupby(by=['continent']).agg(['min', 'max'])

df.groupby(by=['continent']).agg({
    'gdpPercap':['mean','max','min'],
    'pop':['sum']
})
# Out:
#               gdpPercap                                    pop
#                    mean          max           min         sum
# continent
# Africa      3089.032605  13206.48452    277.551859   929539692
# Americas   11003.031625  42951.65309   1201.637154   898871184
# Asia       12473.026870  47306.98978    944.000000  3811953827
# Europe     25054.481636  49357.19017   5937.029526   586098529
# Oceania    29810.188275  34435.36744  25185.009110    24549947

# %%
df.groupby('continent').agg(
    mean_gdp= ('gdpPercap','mean'),
    min_gdp = ('gdpPercap','min'),
    max_gdp = ('gdpPercap','max'),
    total_population = ('pop','sum')
)
# Out:
#                mean_gdp       min_gdp      max_gdp  total_population
# continent
# Africa      3089.032605    277.551859  13206.48452         929539692
# Americas   11003.031625   1201.637154  42951.65309         898871184
# Asia       12473.026870    944.000000  47306.98978        3811953827
# Europe     25054.481636   5937.029526  49357.19017         586098529
# Oceania    29810.188275  25185.009110  34435.36744          24549947

# %%
df
# Out:
#                 country       pop continent  lifeExp     gdpPercap
# 0           Afghanistan  31889923      Asia   43.828    974.580338
# 1               Albania   3600523    Europe   76.423   5937.029526
# 2               Algeria  33333216    Africa   72.301   6223.367465
# 3                Angola  12420476    Africa   42.731   4797.231267
# 4             Argentina  40301927  Americas   75.320  12779.379640
# ..                  ...       ...       ...      ...           ...
# 137             Vietnam  85262356      Asia   74.249   2441.576404
# 138  West Bank and Gaza   4018332      Asia   73.422   3025.349798
# 139         Yemen, Rep.  22211743      Asia   62.698   2280.769906
# 140              Zambia  11746035    Africa   42.384   1271.211593
# 141            Zimbabwe  12311143    Africa   43.487    469.709298
#
# [142 rows x 5 columns]

# %%
df[['country', 'pop', 'lifeExp']]
# Out:
#                 country       pop  lifeExp
# 0           Afghanistan  31889923   43.828
# 1               Albania   3600523   76.423
# 2               Algeria  33333216   72.301
# 3                Angola  12420476   42.731
# 4             Argentina  40301927   75.320
# ..                  ...       ...      ...
# 137             Vietnam  85262356   74.249
# 138  West Bank and Gaza   4018332   73.422
# 139         Yemen, Rep.  22211743   62.698
# 140              Zambia  11746035   42.384
# 141            Zimbabwe  12311143   43.487
#
# [142 rows x 3 columns]

# %%
df.sort_values(['country'],ascending=True)
# Out:
#                 country       pop continent  lifeExp     gdpPercap
# 0           Afghanistan  31889923      Asia   43.828    974.580338
# 1               Albania   3600523    Europe   76.423   5937.029526
# 2               Algeria  33333216    Africa   72.301   6223.367465
# 3                Angola  12420476    Africa   42.731   4797.231267
# 4             Argentina  40301927  Americas   75.320  12779.379640
# ..                  ...       ...       ...      ...           ...
# 137             Vietnam  85262356      Asia   74.249   2441.576404
# 138  West Bank and Gaza   4018332      Asia   73.422   3025.349798
# 139         Yemen, Rep.  22211743      Asia   62.698   2280.769906
# 140              Zambia  11746035    Africa   42.384   1271.211593
# 141            Zimbabwe  12311143    Africa   43.487    469.709298
#
# [142 rows x 5 columns]

# %%
df.sort_values(['gdpPercap'],ascending=False)
# Out:
#               country        pop continent  lifeExp     gdpPercap
# 95             Norway    4627926    Europe   80.196  49357.190170
# 71             Kuwait    2505559      Asia   77.588  47306.989780
# 113         Singapore    4553009      Asia   79.972  47143.179640
# 134     United States  301139947  Americas   78.242  42951.653090
# 62            Ireland    4109086    Europe   78.885  40675.996350
# ..                ...        ...       ...      ...           ...
# 52      Guinea-Bissau    1472041    Africa   46.388    579.231743
# 141          Zimbabwe   12311143    Africa   43.487    469.709298
# 17            Burundi    8390505    Africa   49.580    430.070692
# 74            Liberia    3193942    Africa   45.678    414.507341
# 27   Congo, Dem. Rep.   64606759    Africa   46.462    277.551859
#
# [142 rows x 5 columns]

# %%
 
df.sort_values(['country','gdpPercap'], ascending=[True,False])
# Out:
#                 country       pop continent  lifeExp     gdpPercap
# 0           Afghanistan  31889923      Asia   43.828    974.580338
# 1               Albania   3600523    Europe   76.423   5937.029526
# 2               Algeria  33333216    Africa   72.301   6223.367465
# 3                Angola  12420476    Africa   42.731   4797.231267
# 4             Argentina  40301927  Americas   75.320  12779.379640
# ..                  ...       ...       ...      ...           ...
# 137             Vietnam  85262356      Asia   74.249   2441.576404
# 138  West Bank and Gaza   4018332      Asia   73.422   3025.349798
# 139         Yemen, Rep.  22211743      Asia   62.698   2280.769906
# 140              Zambia  11746035    Africa   42.384   1271.211593
# 141            Zimbabwe  12311143    Africa   43.487    469.709298
#
# [142 rows x 5 columns]

# %%
df.sort_values(['pop'],ascending=False).head(20)
# Out:
#               country         pop continent  lifeExp     gdpPercap
# 24              China  1318683096      Asia   72.961   4959.114854
# 58              India  1110396331      Asia   64.698   2452.210407
# 134     United States   301139947  Americas   78.242  42951.653090
# 59          Indonesia   223547000      Asia   70.650   3540.651564
# 14             Brazil   190010647  Americas   72.390   9065.800825
# 97           Pakistan   169270617      Asia   65.483   2605.947580
# 8          Bangladesh   150448339      Asia   64.062   1391.253792
# 94            Nigeria   135031164    Africa   46.859   2013.977305
# 66              Japan   127467972      Asia   82.603  31656.068060
# 82             Mexico   108700891  Americas   76.195  11977.574960
# 101       Philippines    91077287      Asia   71.688   3190.481016
# 137           Vietnam    85262356      Asia   74.249   2441.576404
# 47            Germany    82400996    Europe   79.406  32170.374420
# ...

# %%
df[df['country']!='China']
# Out:
#                 country       pop continent  lifeExp     gdpPercap
# 0           Afghanistan  31889923      Asia   43.828    974.580338
# 1               Albania   3600523    Europe   76.423   5937.029526
# 2               Algeria  33333216    Africa   72.301   6223.367465
# 3                Angola  12420476    Africa   42.731   4797.231267
# 4             Argentina  40301927  Americas   75.320  12779.379640
# ..                  ...       ...       ...      ...           ...
# 137             Vietnam  85262356      Asia   74.249   2441.576404
# 138  West Bank and Gaza   4018332      Asia   73.422   3025.349798
# 139         Yemen, Rep.  22211743      Asia   62.698   2280.769906
# 140              Zambia  11746035    Africa   42.384   1271.211593
# 141            Zimbabwe  12311143    Africa   43.487    469.709298
#
# [141 rows x 5 columns]

# %%
df.drop(df[  df['country']=='China' ].index   )
# Out:
#                 country       pop continent  lifeExp     gdpPercap
# 0           Afghanistan  31889923      Asia   43.828    974.580338
# 1               Albania   3600523    Europe   76.423   5937.029526
# 2               Algeria  33333216    Africa   72.301   6223.367465
# 3                Angola  12420476    Africa   42.731   4797.231267
# 4             Argentina  40301927  Americas   75.320  12779.379640
# ..                  ...       ...       ...      ...           ...
# 137             Vietnam  85262356      Asia   74.249   2441.576404
# 138  West Bank and Gaza   4018332      Asia   73.422   3025.349798
# 139         Yemen, Rep.  22211743      Asia   62.698   2280.769906
# 140              Zambia  11746035    Africa   42.384   1271.211593
# 141            Zimbabwe  12311143    Africa   43.487    469.709298
#
# [141 rows x 5 columns]

# %%
df.columns = df.columns.str.title()

# %%
df.columns
# Out:
# Index(['Country', 'Pop', 'Continent', 'Lifeexp', 'Gdppercap'], dtype='str')

# %%
df.rename(columns={'Pop': 'Population' ,'GdpPercap':'GDP_Percap' }, inplace=True)

# %%
df
# Out:
#                 Country  Population Continent  Lifeexp     Gdppercap
# 0           Afghanistan    31889923      Asia   43.828    974.580338
# 1               Albania     3600523    Europe   76.423   5937.029526
# 2               Algeria    33333216    Africa   72.301   6223.367465
# 3                Angola    12420476    Africa   42.731   4797.231267
# 4             Argentina    40301927  Americas   75.320  12779.379640
# ..                  ...         ...       ...      ...           ...
# 137             Vietnam    85262356      Asia   74.249   2441.576404
# 138  West Bank and Gaza     4018332      Asia   73.422   3025.349798
# 139         Yemen, Rep.    22211743      Asia   62.698   2280.769906
# 140              Zambia    11746035    Africa   42.384   1271.211593
# 141            Zimbabwe    12311143    Africa   43.487    469.709298
#
# [142 rows x 5 columns]

# %%
df.loc[df['Continent']=='Africa','Lifeexp'] +=2

# %%
df
# Out:
#                 Country  Population Continent  Lifeexp     Gdppercap
# 0           Afghanistan    31889923      Asia   43.828    974.580338
# 1               Albania     3600523    Europe   76.423   5937.029526
# 2               Algeria    33333216    Africa   74.301   6223.367465
# 3                Angola    12420476    Africa   44.731   4797.231267
# 4             Argentina    40301927  Americas   75.320  12779.379640
# ..                  ...         ...       ...      ...           ...
# 137             Vietnam    85262356      Asia   74.249   2441.576404
# 138  West Bank and Gaza     4018332      Asia   73.422   3025.349798
# 139         Yemen, Rep.    22211743      Asia   62.698   2280.769906
# 140              Zambia    11746035    Africa   44.384   1271.211593
# 141            Zimbabwe    12311143    Africa   45.487    469.709298
#
# [142 rows x 5 columns]

# %%
df.iloc[141] = ['Zimbabwe',None,None,None,None]


df[df.isna().any(axis=1)]
# Out:
#       Country  Population Continent  Lifeexp  Gdppercap
# 141  Zimbabwe         NaN       NaN      NaN        NaN

# %%
df.fillna({col: 0 for col in df.select_dtypes(include='number').columns}, inplace=True)
# Out:
#                 Country  Population Continent  Lifeexp     Gdppercap
# 0           Afghanistan  31889923.0      Asia   43.828    974.580338
# 1               Albania   3600523.0    Europe   76.423   5937.029526
# 2               Algeria  33333216.0    Africa   74.301   6223.367465
# 3                Angola  12420476.0    Africa   44.731   4797.231267
# 4             Argentina  40301927.0  Americas   75.320  12779.379640
# ..                  ...         ...       ...      ...           ...
# 137             Vietnam  85262356.0      Asia   74.249   2441.576404
# 138  West Bank and Gaza   4018332.0      Asia   73.422   3025.349798
# 139         Yemen, Rep.  22211743.0      Asia   62.698   2280.769906
# 140              Zambia  11746035.0    Africa   44.384   1271.211593
# 141            Zimbabwe         0.0       NaN    0.000      0.000000
#
# [142 rows x 5 columns]
