# %% [markdown]
# Topic: Matplotlib
# Assignment 5

# %% [markdown]
# 1.	Draw line chart to show urban and rural population of India over the years using population.csv [rural 	population is the difference between total population and urban population]

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('Population.csv')
df
# Out:
#     Year    Population Yearly % Change  Yearly Change  Median Age  \
# 0   1955  3.877009e+08           2.29%      8284413.0        19.7
# 1   1960  4.359903e+08           2.38%      9657890.0        19.2
# 2   1965  4.901401e+08           2.37%     10829962.0        18.5
# 3   1970  5.458643e+08           2.18%     11144824.0        18.1
# 4   1975  6.113095e+08           2.29%     13089053.0        18.4
# 5   1980  6.873540e+08           2.37%     15208898.0        18.9
# 6   1985  7.726478e+08           2.37%     17058754.0        19.3
# 7   1990  8.649722e+08           2.28%     18464886.0        19.7
# 8   1995  9.603010e+08           2.11%     19065765.0        20.3
# 9   2000  1.057923e+09           1.96%     19524338.0        21.2
# 10  2005  1.154676e+09           1.77%     19350718.0        22.2
# 11  2010  1.243482e+09           1.49%     17761048.0        23.6
# 12  2015  1.328024e+09           1.32%     16908587.0        25.3
# ...

# %%
df['Rural Population'] = df['Population'] - df['Urban Population']

# %%
df['Year'].max()
# Out:
# np.int64(2025)

# %%
plt.plot(df['Year'],df['Urban Population'],ls = '--' ,lw = 1)
plt.plot(df['Year'],df['Rural Population'],ls = '--' ,lw = 1)
plt.ylabel('Population')
plt.xlabel('year')
plt.legend(['Urban Population','Rural Population'])
plt.figure(figsize=(2,2 ))
plt.show()

# %%
df
# Out:
#     Year    Population Yearly % Change  Yearly Change  Median Age  \
# 0   1955  3.877009e+08           2.29%      8284413.0        19.7
# 1   1960  4.359903e+08           2.38%      9657890.0        19.2
# 2   1965  4.901401e+08           2.37%     10829962.0        18.5
# 3   1970  5.458643e+08           2.18%     11144824.0        18.1
# 4   1975  6.113095e+08           2.29%     13089053.0        18.4
# 5   1980  6.873540e+08           2.37%     15208898.0        18.9
# 6   1985  7.726478e+08           2.37%     17058754.0        19.3
# 7   1990  8.649722e+08           2.28%     18464886.0        19.7
# 8   1995  9.603010e+08           2.11%     19065765.0        20.3
# 9   2000  1.057923e+09           1.96%     19524338.0        21.2
# 10  2005  1.154676e+09           1.77%     19350718.0        22.2
# 11  2010  1.243482e+09           1.49%     17761048.0        23.6
# 12  2015  1.328024e+09           1.32%     16908587.0        25.3
# ...

# %% [markdown]
# 2. 	Using a Bar chart display India's total, urban and rural population from year 2020 to 2025

# %%
df['Year'].loc[13:]
# Out:
# 13    2020
# 14    2022
# 15    2023
# 16    2024
# 17    2025
# Name: Year, dtype: int64

# %%
xwidth = 0.3
x_year = df['Year'].loc[13:]
plt.figure(figsize=(12,6))
b1 = plt.bar(x_year-xwidth, df['Rural Population'].loc[13:],width =xwidth, label='Rural Population' ,color="#adc527")
b2 = plt.bar(x_year, df['Urban Population'].loc[13:],width =xwidth, label='Urban Population',color="#143686")
b3 = plt.bar(x_year+xwidth, df['Population'].loc[13:],width =xwidth, label='Total Population',color="#D9CEEBD7")

plt.bar_label(b1, fmt='{:,.0f}', padding=-70, rotation=85, fontsize=7)
plt.bar_label(b2, fmt='{:,.0f}', padding=-70, rotation=85, fontsize=7)
plt.bar_label(b3, fmt='{:,.0f}', padding=-70, rotation=85, fontsize=7)



plt.xticks(rotation=30)
plt.xlabel("population")
plt.ylabel("total")
plt.title("Solar Energy Installed Capacity by State")
plt.legend()

plt.ylim(0,df['Population'].loc[13:].max()*1.20)

plt.show()

# %%
xwidth = 0.3
x_year = df['Year'].loc[13:]

plt.bar(x_year, df['Population'].loc[13:],width =0.6, label='Total Population',color="#D9CEEBD7")
plt.bar(x_year-xwidth/2, df['Rural Population'].loc[13:],width =xwidth, label='Rural Population' ,color="#adc527")
plt.bar(x_year+xwidth/2, df['Urban Population'].loc[13:],width =xwidth, label='Urban Population',color="#143686")


plt.xticks(rotation=30)
plt.xlabel("population")
plt.ylabel("total")
plt.title("Solar Energy Installed Capacity by State")
plt.legend()

plt.show()

# %%
df.dtypes
# Out:
# Year                  int64
# Population          float64
# Yearly % Change         str
# Yearly Change       float64
# Median Age          float64
# Fertility Rate      float64
# Density               int64
# Urban Pop %             str
# Urban Population    float64
# Country's Share         str
# World Population    float64
# Rural Population    float64
# dtype: object

# %% [markdown]
# 3.	Using gapminder2007.csv show life expectancy of top 10 highly populated countries from Asia

# %%
df= pd.read_csv('gapminder2007.csv')
df
# Out:
#                 country       pop continent  lifeExp     gdpPercap
# 0           Afghanistan  31889923      Asia   43.828    974.580338
# 1               Albania   3600523    Europe   76.423   5937.029526
# 2               Algeria  33333216    Africa   72.301   6223.367465
# 3                Angola  12420476    Africa   42.731   4797.231267
# 4             Argentina  40301927  Americas   75.320  12779.379640
# ..                  ...       ...       ...      ...           ...
# 137             Vietnam  85262356      Asia   74.249   2441.576404
# 138  West Bank and Gaza   4018332      Asia   73.422   3025.349798
# 139         Yemen, Rep.  22211743      Asia   62.698   2280.769906
# 140              Zambia  11746035    Africa   42.384   1271.211593
# 141            Zimbabwe  12311143    Africa   43.487    469.709298
#
# [142 rows x 5 columns]

# %%
df.groupby('continent').get_group('Asia').sort_values('lifeExp',ascending=False).head(10)
# Out:
#               country        pop continent  lifeExp     gdpPercap
# 66              Japan  127467972      Asia   82.603  31656.068060
# 55   Hong Kong, China    6980412      Asia   82.208  39724.978670
# 63             Israel    6426679      Asia   80.745  25523.277100
# 113         Singapore    4553009      Asia   79.972  47143.179640
# 70        Korea, Rep.   49044790      Asia   78.623  23348.139730
# 125            Taiwan   23174294      Asia   78.400  28718.276840
# 71             Kuwait    2505559      Asia   77.588  47306.989780
# 96               Oman    3204897      Asia   75.640  22316.192870
# 7             Bahrain     708573      Asia   75.635  29796.048340
# 137           Vietnam   85262356      Asia   74.249   2441.576404

# %% [markdown]
# 3.	Using a pie chart show distribution of top six selling cars [Create data as required]

# %%
import random

random.seed(42)
car_names = [
    'Nexon', 'WagonR', 'Swift', 'Baleno', 'Brezza',
    'Punch', 'Creta', 'Venue', 'i20', 'Seltos',
    'Sonet', 'Thar', 'Scorpio', 'XUV700', 'Alto',
    'Ertiga', 'Fronx', 'Dzire', 'Harrier', 'Tiago'
]
data = {
    'name':  [ 'Nexon', 'WagonR', 'Swift', 'Baleno', 'Brezza', 'Punch', 'Creta', 'Venue', 'i20', 'Seltos',
                'Sonet', 'Thar', 'Scorpio', 'XUV700', 'Alto', 'Ertiga', 'Fronx', 'Dzire', 'Harrier', 'Tiago' ],
    'price': [random.randint(15000, 50000) for _ in car_names],
    'sell count': [random.randint(100, 1000) for _ in car_names]
}

df = pd.DataFrame(data)
df
# Out:
#        name  price  sell count
# 0     Nexon  22296         703
# 1    WagonR  16639         384
# 2     Swift  33024         928
# 3    Baleno  31049         990
# 4    Brezza  29628         106
# 5     Punch  24144         877
# 6     Creta  21717         925
# 7     Venue  20697         263
# 8       i20  42651         814
# 9    Seltos  17082         532
# 10    Sonet  16952         448
# 11     Thar  21140         384
# 12  Scorpio  29328         259
# 13   XUV700  30247         320
# 14     Alto  48118         881
# 15   Ertiga  16739         444
# 16    Fronx  28031         204
# 17    Dzire  42493         194
# 18  Harrier  29446         489
# 19    Tiago  44439         199

# %%
carsdf = df.sort_values('sell count',ascending=False).head(6)
carsdf
# Out:
#       name  price  sell count
# 3   Baleno  31049         990
# 2    Swift  33024         928
# 6    Creta  21717         925
# 14    Alto  48118         881
# 5    Punch  24144         877
# 8      i20  42651         814

# %%
plt.pie(carsdf['sell count'],
        labels=carsdf['name'],
        colors=['red','orange','blue','brown','violet','green'],
        shadow= 1,
        autopct='%1.2f%%',
        explode=[0.2,0,0,0,0,0],
        wedgeprops={'edgecolor':'black','linewidth':0.8, 'width':1.0,'linestyle':'--'},

            )
plt.title('Sell count of cars')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# 4.	Using Histogram show distribution of developers by their experience [use survey_data_sample.csv]
