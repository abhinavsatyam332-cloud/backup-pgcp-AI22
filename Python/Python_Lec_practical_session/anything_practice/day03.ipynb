# %%
def add(a:str , b:int):
    return a+b

# %%
add(5,10)
# Out:
# 15

# %%
def funnn(name="fs",price=10):
    print(f'{name} and {price}')

funnn(price=1000)
# Out:
# fs and 1000

# %%
def sumx(*args, **kargs):
    print(args)
    print(kargs)
    name, age = kargs
    print(f'Name = {name}')

sumx(2,3,4,name = 'xyz', age = 23)
# Out:
# (2, 3, 4)
# {'name': 'xyz', 'age': 23}
# Name = name
